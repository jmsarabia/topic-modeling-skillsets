# %%
from bertopic import BERTopic
from sentence_transformers import SentenceTransformer
from hdbscan import HDBSCAN
from bertopic.vectorizers import ClassTfidfTransformer
from gensim.models.coherencemodel import CoherenceModel
from sklearn.feature_extraction.text import CountVectorizer
from bertopic.vectorizers import ClassTfidfTransformer
import pandas as pd
import numpy as np
import time
import gensim.corpora as corpora
script_start_time = time.time()


folder_path = "YOUR_FILE_PATH"

# %%
def replaceKeyword(x, keyword_list):
    '''
    Input:
    - x: input string
    - keyword_list: list of keywords to replace with
    Output:
    - label: string of fixed word. If keywords do not exist in string, return None
    '''
    label=None
    for keyword in keyword_list:
        if label == None:
            try: 
                if keyword in x:
                    label=keyword
            except:
                label=None
    
    if label== None:
        return "other"
    else:
        return label


def simplifyJobs(df):
    '''
    Input:
    - df: dataframe of job postings
    Output:
    - docs: list of strings representing input documents. The job postings are simplified.
    '''
    shortened_dict = {'Machine Learning': 'ML', 'Business Intelligence': 'BI', 'Developer Operations': 'DevOps', 'Artificial Intelligence': 'AI'}
    job_titles=['DataAnalyst','DataEngineer','DataScientist','MachineLearningEngineer', 'BIAnalyst',
           'AIEngineer','SoftwareEngineer','DevOpsEngineer','Architect','BigDataEngineer', 'ResearchScientist']
    df = df.dropna(thresh = 5)
    df['Job Title'] = df['Job Title'].str.replace(' ', '') # shorten job title
    df['Job Title'] = df['Job Title'].replace(shortened_dict, regex = True)
    df['JobTitleClean'] = pd.Series( [replaceKeyword(x, job_titles ) for x in df['Job Title']])
    df['JobTitleClean'] = df['JobTitleClean'].fillna("other") # other for all jobs not in title
    df['Requirment of the company '] = df['Requirment of the company '].fillna('Unknown Company')
    df['Experience level'] = df['Experience level'].fillna('Unknown Experience Level')
    df['posting'] = df['JobTitleClean'] + " " + df['Requirment of the company '] + " " + df['Experience level'] # not including company
    df['posting'] = df['posting'].str.replace(",", " ")
    df['posting'] = df['posting'].str.replace("-", "")
    docs = df['posting'].to_list()
    return docs

# %%
# Embedding model: See [1] for more details 
embedding_model = SentenceTransformer("all-MiniLM-L6-v2")

# Clustering model: See [2] for more details
cluster_model = HDBSCAN(min_cluster_size = 15, 
                        metric = 'euclidean', 
                        cluster_selection_method = 'eom', 
                        prediction_data = True)
# Out:
# modules.json: 100%|█████████████████████████████████████████████████████████████████████████████████| 349/349 [00:00<00:00, 120kB/s]
# config_sentence_transformers.json: 100%|███████████████████████████████████████████████████████████| 116/116 [00:00<00:00, 29.0kB/s]
# README.md: 100%|███████████████████████████████████████████████████████████████████████████████| 10.7k/10.7k [00:00<00:00, 2.13MB/s]
# sentence_bert_config.json: 100%|█████████████████████████████████████████████████████████████████| 53.0/53.0 [00:00<00:00, 13.2kB/s]
# config.json: 100%|██████████████████████████████████████████████████████████████████████████████████| 612/612 [00:00<00:00, 150kB/s]
# pytorch_model.bin: 100%|███████████████████████████████████████████████████████████████████████| 90.9M/90.9M [00:22<00:00, 4.00MB/s]
# tokenizer_config.json: 100%|███████████████████████████████████████████████████████████████████████| 350/350 [00:00<00:00, 70.2kB/s]
# vocab.txt: 100%|█████████████████████████████████████████████████████████████████████████████████| 232k/232k [00:00<00:00, 3.19MB/s]
# tokenizer.json: 100%|████████████████████████████████████████████████████████████████████████████| 466k/466k [00:00<00:00, 3.05MB/s]
# special_tokens_map.json: 100%|█████████████████████████████████████████████████████████████████████| 112/112 [00:00<00:00, 28.6kB/s]
# 1_Pooling/config.json: 100%|███████████████████████████████████████████████████████████████████████| 190/190 [00:00<00:00, 46.5kB/s]

# %%
df = pd.read_csv('ai-jobs_data_science_job.csv', encoding = 'latin-1')

docs = simplifyJobs(df)
docs
# Out:
# ['DataAnalyst Computer Science Data quality Genetics Mathematics SAS Statistics Entrylevel',
#  'DataAnalyst Agile Data management Finance Security   Entrylevel',
#  'MachineLearningEngineer Agile Architecture AWS Computer Science Computer Vision Deep Learning Unknown Experience Level',
#  'DataAnalyst Engineering Industrial Oracle Power BI R R&D Entrylevel',
#  'DataEngineer AWS Azure Computer Science Consulting Dataflow Data pipelines Midlevel',
#  'DataScientist Computer Science Deep Learning Industrial Machine Learning NLP NumPy Seniorlevel',
#  'other Banking Data quality Excel Security   Entrylevel',
#  'other Business Intelligence Excel Genetics    Entrylevel',
#  'DataEngineer Big Data Computer Science Engineering Machine Learning Mathematics Matlab Entrylevel',
#  'DataEngineer Agile APIs AWS Azure Big Data Computer Science Seniorlevel',
#  'DataScientist Computer Science Data analysis Deep Learning Keras Machine Learning PhD Entrylevel',
#  'DataAnalyst Business Analytics Business Intelligence Data management Economics Engineering Genetics Unknown Experience Level',
#  'other Data Analytics Excel Finance Market research Power BI Privacy Entrylevel',
#  'other Data management Engineering R Spark   Seniorlevel',
#  'other BigQuery Data Analytics LLMs Pandas Python  Entrylevel',
#  'DataScientist Computer Science Deep Learning Industrial Machine Learning NLP NumPy Seniorlevel',
#  'MachineLearningEngineer AWS CUDA Docker Git GitHub GitLab Seniorlevel',
#  'DataAnalyst BigQuery Excel Finance Python R Redshift Seniorlevel',
#  'BIAnalyst Business Analytics Business Intelligence Data warehouse Looker Python R Unknown Experience Level',
#  'DataScientist Agile Data visualization Economics Machine Learning Mathematics Metabase Seniorlevel',
#  'DataAnalyst Architecture Data analysis Data Analytics Data quality Data visualization Ecommerce Seniorlevel',
#  'DataEngineer Agile Airflow Clustering Computer Science Data governance Data Mining Seniorlevel',
#  'other Agile Azure Big Data Blockchain Databricks Data management Entrylevel',
#  'other Airflow APIs Architecture Azure Clustering Computer Science Entrylevel',
#  'DataEngineer Computer Science Data Mining Engineering Python SQL Statistics Midlevel',
#  'DataScientist Agile CI/CD Computer Vision Data quality Data visualization Deep Learning Entrylevel',
#  'DataEngineer Airflow Architecture AWS Data warehouse DevOps ETL Entrylevel',
#  'other Agile Architecture Business Intelligence Data analysis Data visualization ETL Seniorlevel',
#  'DataScientist Banking Blockchain Crypto Data pipelines Engineering Fraud risk Seniorlevel',
#  'DataAnalyst Clustering Looker Python SQL Tableau  Seniorlevel',
#  'other Cybernetics DataRobot Engineering Keras Machine Learning Python Seniorlevel',
#  'other Data Analytics Engineering Excel Industrial Statistics  Seniorlevel',
#  'DataEngineer APIs Big Data Computer Science Data analysis Data pipelines Data quality Seniorlevel',
#  'other A/B testing Angular APIs Computer Science Engineering JavaScript Seniorlevel',
#  'SoftwareEngineer Big Data CI/CD Computer Science Computer Vision Data pipelines Data Warehousing Seniorlevel',
#  'DataScientist Agile Airflow Big Data BigQuery Computer Science Data analysis Seniorlevel',
#  'other A/B testing Data visualization Economics Engineering Mathematics Power BI Unknown Experience Level',
#  'other Business Intelligence Ecommerce Python SQL Tableau  Seniorlevel',
#  'other A/B testing Business Intelligence Data visualization KPIs Looker Mathematics Seniorlevel',
#  'DataScientist Big Data Data Mining Machine Learning Mathematics ML models PhD Seniorlevel',
#  'DataEngineer Agile Big Data Business Intelligence Data Mining Data visualization Engineering Seniorlevel',
#  'other Architecture Data governance Data management Engineering KPIs Privacy Seniorlevel',
#  'DataEngineer Airflow Architecture AWS Big Data BigQuery CI/CD Midlevel',
#  'other Data management Excel Finance Mathematics ML models Privacy Seniorlevel',
#  'other CI/CD Computer Science Data pipelines Deep Learning Oracle Pipelines Entrylevel',
#  'DataAnalyst Business Intelligence Engineering Genetics Git Pandas Python Midlevel',
#  'DataScientist Agile APIs Architecture AWS Big Data Classification Seniorlevel',
#  'DataAnalyst Agile Data analysis Data visualization Economics KPIs Mathematics Seniorlevel',
#  'other Business Intelligence Data analysis Data Analytics PhD Privacy Python Midlevel',
#  'DataEngineer Airflow Architecture AWS Banking Big Data BigQuery Seniorlevel',
#  'DataAnalyst Blockchain Computer Science Data analysis Data governance Data management Data quality Seniorlevel',
#  'other AWS Bigtable Data analysis DevOps Distributed Systems Engineering Seniorlevel',
#  'DataScientist A/B testing Banking Data Mining Finance Looker Python Seniorlevel',
#  'other AWS Deep Learning GCP Generative modeling LLMs Machine Learning Seniorlevel',
#  'DataAnalyst APIs AWS Computer Science Data analysis Data pipelines Excel Midlevel',
#  'DataScientist AWS Azure Big Data Business Intelligence Computer Science Data management Midlevel',
#  'other Computer Science DataOps Engineering Market research Research Testing Seniorlevel',
#  'other Business Intelligence Computer Science Data analysis Data governance Data quality Data visualization Entrylevel',
#  'other Agile Finance JavaScript Testing   Midlevel',
#  'other Agile APIs Architecture Business Intelligence Computer Science Data management Seniorlevel',
#  'DataScientist Big Data Data governance Data visualization Engineering Finance Hadoop Seniorlevel',
#  'DataAnalyst Agile Data management Data quality Excel   Seniorlevel',
#  'other Agile Computer Science Data visualization Engineering JavaScript Mathematics Seniorlevel',
#  'DataEngineer AWS BigQuery Business Intelligence CI/CD Dagster Data pipelines Midlevel',
#  'DataEngineer AWS Azure Consulting Data Analytics Databricks Data Warehousing Seniorlevel',
#  'DataEngineer Architecture AWS Big Data Business Intelligence Data pipelines Data quality Seniorlevel',
#  'other Machine Learning Physics     Midlevel',
#  'DataScientist Causal inference Computer Science Data Mining Economics Machine Learning Mathematics Seniorlevel',
#  'other Banking Business Intelligence Consulting Economics Engineering Excel Seniorlevel',
#  'DataAnalyst Business Intelligence Computer Science CX Data visualization Ecommerce Engineering Unknown Experience Level',
#  'MachineLearningEngineer Architecture AWS Big Data Classification Data Mining Data pipelines Seniorlevel',
#  'other Agile Autonomous Driving Docker Linux Python Testing Seniorlevel',
#  'DataEngineer Agile Airflow Architecture Big Data Computer Science Data Analytics Seniorlevel',
#  'Architect Architecture Big Data Computer Science Databricks Deep Learning Engineering Seniorlevel',
#  'DataScientist Causal inference Economics Engineering Finance Machine Learning PhD Seniorlevel',
#  'DataAnalyst Matplotlib MongoDB NumPy Pandas Power BI Python Entrylevel',
#  'other APIs Finance GitHub JavaScript Jira React Midlevel',
#  'other Finance Research Testing    Executivelevel',
#  'other Data governance Data quality Finance Research   Entrylevel',
#  'DataAnalyst Computer Science Consulting Consulting firm Data analysis Data quality Engineering Seniorlevel',
#  'other Banking Data management MySQL SQL   Midlevel',
#  'other AWS Azure Computer Science Finance GANs GCP Executivelevel',
#  'other Architecture Azure Business Intelligence Computer Science Databricks Data governance Midlevel',
#  'other Athena AWS Business Intelligence Computer Science Data Analytics Data quality Seniorlevel',
#  'DataAnalyst Big Data Computer Science Data Analytics Databricks Ecommerce Economics Seniorlevel',
#  'MachineLearningEngineer A/B testing Airflow AWS Cassandra Computer Science Computer Vision Seniorlevel',
#  'DataAnalyst BigQuery Business Intelligence Dagster Databricks Data Warehousing ELT Midlevel',
#  'DataScientist Causal inference Computer Science Consulting Data visualization Economics Engineering Seniorlevel',
#  'DataEngineer AWS Big Data Computer Science Data pipelines DevOps Engineering Seniorlevel',
#  'other AWS Big Data Computer Science GCP Snowflake SQL Seniorlevel',
#  'MachineLearningEngineer Architecture Big Data Cassandra Computer Science Data Mining Deep Learning Seniorlevel',
#  'DataAnalyst Classification Consulting Data management Power BI Python R Midlevel',
#  'DataAnalyst Data Analytics Data visualization Excel Finance PhD Power BI Seniorlevel',
#  'DataEngineer APIs Azure Computer Science Data pipelines Engineering ETL Unknown Experience Level',
#  'other Big Data Consulting Consulting firm Econometrics Finance Machine Learning Entrylevel',
#  'other Biology Computer Science Data management Data quality Data visualization GCP Seniorlevel',
#  'DataAnalyst Data analysis Research     Unknown Experience Level',
#  'other Big Data Consulting Consulting firm Econometrics Finance Machine Learning Entrylevel',
#  'MachineLearningEngineer AWS Azure BERT Chatbots Classification Deep Learning Seniorlevel',
#  'other AWS Azure BigQuery Computer Science Dataflow Dataproc Seniorlevel',
#  'other AWS Azure BigQuery Computer Science Dataflow Dataproc Seniorlevel',
#  'DataEngineer Agile Airflow APIs Architecture Banking Blockchain Seniorlevel',
#  'DataEngineer APIs Architecture Data pipelines Engineering JavaScript NoSQL Seniorlevel',
#  'DataScientist Big Data BigQuery Data governance Data visualization Engineering Finance Seniorlevel',
#  'other Angular APIs Architecture ASR AWS Azure Executivelevel',
#  'DataAnalyst A/B testing Banking Engineering FinTech KPIs Looker Seniorlevel',
#  'DataAnalyst APIs Business Analytics Engineering ETL Git Jira Seniorlevel',
#  'other Agile Computer Vision CX Engineering Machine Learning Prototyping Entrylevel',
#  'DataEngineer Ansible AWS Data pipelines DevOps Elasticsearch Engineering Seniorlevel',
#  'DataEngineer Airflow APIs AWS Azure Data Analytics Data pipelines Midlevel',
#  'other Architecture Big Data Engineering Machine Learning Privacy Python Unknown Experience Level',
#  'other Architecture Banking Computer Science Consulting Credit risk Docker Seniorlevel',
#  'DataEngineer APIs ETL GCP Google Cloud Hadoop JavaScript Entrylevel',
#  'SoftwareEngineer Big Data CI/CD Computer Science Computer Vision Data pipelines Data Warehousing Seniorlevel',
#  'DataScientist Computer Science Data quality Engineering Feature engineering GCP Machine Learning Seniorlevel',
#  'DataScientist Computer Science Data analysis EDA Engineering Git GitHub Midlevel',
#  'DataEngineer AWS Azure Data management Data Warehousing Engineering ETL Entrylevel',
#  'other Architecture Consulting Data governance Data management Data strategy Machine Learning Seniorlevel',
#  'Architect APIs Architecture JSON Model design Security SQL Seniorlevel',
#  'DataEngineer Agile Airtable AWS Databricks Engineering PostgreSQL Midlevel',
#  'DataScientist AWS Azure Computer Science Data management Data visualization Deep Learning Seniorlevel',
#  'DataEngineer Architecture AWS Data Analytics Data warehouse DynamoDB Elasticsearch Midlevel',
#  'DataAnalyst Computer Science Consulting Consulting firm Data analysis Data quality Engineering Seniorlevel',
#  'DataScientist Bayesian Business Analytics Classification Data analysis Data Analytics Data Mining Seniorlevel',
#  'other AWS DevOps Docker EC2 Engineering Kubernetes Seniorlevel',
#  'other AWS Big Data Business Intelligence Data Mining Data quality Data visualization Unknown Experience Level',
#  'other Airflow AWS Banking Blockchain Classification Computer Science Seniorlevel',
#  'MachineLearningEngineer Machine Learning OOP Python Research Testing  Seniorlevel',
#  'other Business Intelligence Clustering Data analysis Data Analytics Data governance Data pipelines Seniorlevel',
#  'DataScientist Airflow Big Data Classification Clustering Computer Science Databricks Unknown Experience Level',
#  'DataEngineer Agile Architecture AWS Big Data BigQuery Computer Science Seniorlevel',
#  'other Biology Consulting Data analysis Data Analytics Data management Data quality Unknown Experience Level',
#  'MachineLearningEngineer Airflow Architecture AWS Big Data CI/CD Databricks Midlevel',
#  'other Computer Science Data governance Power BI Research   Unknown Experience Level',
#  'DataEngineer Clustering Computer Science Data analysis Data Analytics Engineering ETL Seniorlevel',
#  'DataEngineer Agile APIs Architecture AWS Azure CI/CD Seniorlevel',
#  'DataEngineer Agile Angular Big Data Blockchain ETL Hadoop Seniorlevel',
#  'other AWS Azure Big Data Computer Science Databricks Elasticsearch Executivelevel',
#  'DataEngineer Architecture BigQuery CI/CD Docker Engineering GCP Entrylevel',
#  'DataEngineer Architecture Azure Big Data BigQuery Data analysis Databricks Midlevel',
#  'DataAnalyst BigQuery Data pipelines Data visualization ELT Engineering ETL Seniorlevel',
#  'other Architecture AWS Business Intelligence Classification Consulting Data visualization Midlevel',
#  'other Agile Architecture KPIs Power BI Privacy R Seniorlevel',
#  'DataEngineer Airflow AWS Business Analytics Databricks DataOps Data pipelines Seniorlevel',
#  'other Computer Science Ecommerce LLMs Machine Learning NLP Research Seniorlevel',
#  'other Data Analytics Industrial     Seniorlevel',
#  'DataAnalyst APIs Big Data Data analysis Data quality GitHub Grafana Entrylevel',
#  'DataEngineer Agile Airflow Architecture AWS Azure Data governance Seniorlevel',
#  'DataScientist AWS Big Data Business Analytics Hadoop Machine Learning Mathematics Executivelevel',
#  'other AWS Business Intelligence CX Data Analytics Data management Data visualization Unknown Experience Level',
#  'other Computer Science Data analysis Deep Learning Diffusion models Drug discovery Genetics Seniorlevel',
#  'other Architecture AWS Elasticsearch Engineering Kafka Kubernetes Seniorlevel',
#  'DataScientist Big Data Computer Science CX Cybernetics Engineering Industrial Entrylevel',
#  'other Airflow AWS Banking Blockchain Crypto Data analysis Unknown Experience Level',
#  'DataEngineer APIs Architecture AWS Azure Big Data CI/CD Entrylevel',
#  'MachineLearningEngineer Computer Science KPIs Machine Learning ML models Research Security Midlevel',
#  'DataAnalyst Airflow Big Data Classification Clustering Data analysis Databricks Seniorlevel',
#  'other Engineering Excel Market research Research   Seniorlevel',
#  'DataAnalyst Data analysis Excel Market research Privacy Research Statistics Entrylevel',
#  'other APIs Architecture AWS BigQuery Business Analytics Computer Science Seniorlevel',
#  'DataEngineer APIs Architecture AWS Azure Big Data CI/CD Seniorlevel',
#  'MachineLearningEngineer AI strategy BigQuery Data Mining Engineering GPT LLMs Seniorlevel',
#  'DataScientist Banking Chatbots Data analysis Engineering FinTech Machine Learning Entrylevel',
#  'other Biology Computer Science Data quality Data visualization Engineering Genetics Seniorlevel',
#  'other AWS DynamoDB Elasticsearch Kafka Kubernetes Linux Seniorlevel',
#  'other APIs AWS Azure Consulting Deep Learning Drones Entrylevel',
#  'other AWS Bayesian Docker Engineering Git Machine Learning Midlevel',
#  'other Consulting GCP Google Cloud Looker Power BI Privacy Seniorlevel',
#  'DataEngineer Airflow AWS Azure Big Data Computer Science Data analysis Seniorlevel',
#  'DataScientist Airflow AWS Data Analytics Data pipelines Engineering Looker Seniorlevel',
#  'other Airflow BigQuery CI/CD Databricks Data quality Data warehouse Entrylevel',
#  'other Data quality Industrial     Executivelevel',
#  'DataEngineer Airflow AWS Banking Blockchain Crypto CX Seniorlevel',
#  'other Architecture AWS DataOps Engineering Privacy Python Entrylevel',
#  'DataAnalyst Airflow AWS Big Data Bitbucket Data Analytics Excel Seniorlevel',
#  'other Bayesian Big Data Computer Science Docker Engineering Git Seniorlevel',
#  'Architect Architecture AWS Azure Big Data Consulting Data Analytics Seniorlevel',
#  'other Agile Computer Science Deep Learning Industrial Linux Machine Learning Entrylevel',
#  'DataEngineer Computer Science Databricks Engineering ETL Excel MLFlow Seniorlevel',
#  'MachineLearningEngineer AWS Azure Big Data Computer Science Computer Vision Consulting Entrylevel',
#  'other Computer Science Computer Vision Deep Learning Engineering Machine Learning ML models Seniorlevel',
#  'DataEngineer Agile APIs Azure Databricks Data management Data pipelines Seniorlevel',
#  'other Banking Computer Science Conversational AI Data analysis Industrial LLMs Executivelevel',
#  'other Business Intelligence Excel Finance Research   Entrylevel',
#  'ResearchScientist Computer Science Data pipelines Deep Learning ICLR ICML Machine Learning Entrylevel',
#  'other Architecture AWS Consulting Distributed Systems DynamoDB Engineering Seniorlevel',
#  'DataScientist A/B testing Bayesian CI/CD Computer Vision Deep Learning Ecommerce Seniorlevel',
#  'DataEngineer Airflow Architecture AWS Data pipelines Engineering FiveTran Seniorlevel',
#  'DataAnalyst A/B testing Banking Business Intelligence Computer Science Consulting Data analysis Seniorlevel',
#  'other Computer Science Engineering GitHub Machine Learning Mathematics ML models Midlevel',
#  'Architect Architecture Azure Business Intelligence DevOps Machine Learning SQL Seniorlevel',
#  'DataScientist Excel Finance GitHub Mathematics R SQL Seniorlevel',
#  'other Big Data Computer Science Data analysis Data management Economics Engineering Seniorlevel',
#  'DataScientist APIs Architecture Clustering Computer Science Data analysis Data Analytics Entrylevel',
#  'other BigQuery Data analysis Data Analytics DataOps Ecommerce Engineering Midlevel',
#  'other Agile AI governance Architecture Big Data Deep Learning Engineering Seniorlevel',
#  'other Computer Science Data Analytics Databricks Engineering Excel LLMs Seniorlevel',
#  'other Computer Science Ecommerce Engineering Jira Robotics  Entrylevel',
#  'Architect Architecture Computer Science Data governance Data management Security  Midlevel',
#  'DataAnalyst Agile Scrum Tableau    Midlevel',
#  'other Architecture Databricks Engineering Excel Industrial LLMs Executivelevel',
#  'other Agile APIs AWS Business Analytics Business Intelligence Data Analytics Seniorlevel',
#  'SoftwareEngineer Computer Science Databricks Machine Learning Python Robotics Scala Seniorlevel',
#  'other Business Intelligence Data visualization Excel Finance Security  Unknown Experience Level',
#  'other Computer Science Data analysis Data Analytics Engineering JavaScript Python Entrylevel',
#  'other Data analysis Engineering FinTech Machine Learning Market research Privacy Seniorlevel',
#  'DataAnalyst A/B testing Banking Business Intelligence Computer Science Consulting Data analysis Seniorlevel',
#  'other Architecture Data management Excel Security   Seniorlevel',
#  'DataEngineer Agile Architecture AWS Azure BigQuery Bigtable Midlevel',
#  'other DataOps Engineering FinTech Jira R R&D Seniorlevel',
#  'ResearchScientist Computer Science Deep Learning ICLR ICML Machine Learning Mathematics Entrylevel',
#  'MachineLearningEngineer AWS Deep Learning GCP Machine Learning ML models Model training Seniorlevel',
#  'MachineLearningEngineer Machine Learning ML models Python R Research Security Entrylevel',
#  'other Computer Science Data management Engineering Excel Industrial Power BI Entrylevel',
#  'DataEngineer Agile Architecture Athena AWS Big Data BigQuery Seniorlevel',
#  'other Consulting Engineering Finance Industrial JavaScript Mathematics Entrylevel',
#  'DataEngineer Agile APIs AWS CX Data management Data pipelines Midlevel',
#  'DataAnalyst Economics Engineering Machine Learning Mathematics SQL  Entrylevel',
#  'DataEngineer Agile Ansible APIs Architecture AWS Azure Midlevel',
#  'DataAnalyst Ecommerce ETL Looker Power BI SQL Tableau Entrylevel',
#  'DataEngineer Airflow Architecture AWS Azure Big Data Databricks Seniorlevel',
#  'other Agile APIs AWS Azure Consulting Databricks Seniorlevel',
#  'SoftwareEngineer Architecture AWS Azure Distributed Systems Docker Engineering Seniorlevel',
#  'DataEngineer Agile Architecture AWS Azure BigQuery Bigtable Seniorlevel',
#  'DataEngineer Agile Architecture Azure Big Data Business Analytics Cassandra Seniorlevel',
#  'DataEngineer Agile Azure Computer Science Databricks Data warehouse DevOps Entrylevel',
#  'other Architecture Computer Science Engineering Machine Learning Robotics  Executivelevel',
#  'DataAnalyst Genetics Git Pipelines Python R Research Seniorlevel',
#  'other Data quality SLAM Streaming    Entrylevel',
#  'other Finance Research Testing    Midlevel',
#  'ResearchScientist Biology Chemistry Computer Science Deep Learning Keras Machine Learning Midlevel',
#  'DataEngineer Agile AWS Azure Consulting Data quality Engineering Unknown Experience Level',
#  'other Architecture AWS Big Data Data Analytics Data warehouse Engineering Seniorlevel',
#  'other Agile APIs AWS Azure CAD Engineering Midlevel',
#  'other Airflow AWS DataOps Docker Engineering HuggingFace Seniorlevel',
#  'DataAnalyst Computer Science Ecommerce Economics Machine Learning Mathematics ML models Unknown Experience Level',
#  'DataScientist AWS Banking Data analysis Deep Learning Engineering Feature engineering Seniorlevel',
#  'DataEngineer AWS Azure BigQuery Business Intelligence Data pipelines Data visualization Unknown Experience Level',
#  'other Architecture BERT Classification Computer Science Deep Learning Engineering Seniorlevel',
#  'DataScientist A/B testing Computer Science Data analysis Data Mining Data visualization Machine Learning Entrylevel',
#  'DataScientist Causal inference Computer Science Data quality Engineering Finance Machine Learning Seniorlevel',
#  'DataAnalyst Blockchain CX Data analysis Data quality Excel Python Seniorlevel',
#  'other Agile Architecture Cluster analysis Consulting CX Data Analytics Midlevel',
#  'other Business Intelligence Computer Science Data analysis Engineering Excel Mathematics Executivelevel',
#  'DataEngineer Agile Airflow Architecture AWS Big Data Computer Science Seniorlevel',
#  'BIAnalyst Business Intelligence Data Analytics Data management Excel Power BI Qlik Unknown Experience Level',
#  'DataAnalyst Agile Business Intelligence Data management Data quality Data Studio Data visualization Midlevel',
#  'DataEngineer Agile Architecture AWS Big Data Computer Science Data pipelines Midlevel',
#  'DataAnalyst A/B testing AWS Data Analytics Ecommerce ETL Finance Unknown Experience Level',
#  'DataScientist Big Data Computer Science Data management ETL GitHub Nonprofit Midlevel',
#  'DataScientist Banking Chatbots Data analysis Engineering FinTech Hadoop Seniorlevel',
#  'other Architecture Autonomous Driving Classification Computer Vision Deep Learning Engineering Seniorlevel',
#  'other A/B testing Data visualization Economics Engineering Mathematics Power BI Entrylevel',
#  'DataEngineer Airflow CI/CD Computer Science Consulting DataOps Data pipelines Seniorlevel',
#  'DataScientist Business Intelligence CX Data visualization Engineering PhD Prototyping Seniorlevel',
#  'SoftwareEngineer Architecture Computer Science Data Analytics Data pipelines Deep Learning Distributed Systems Unknown Experience Level',
#  'DataEngineer AWS Banking ETL FinTech NLP Python Midlevel',
#  'DataScientist Agile APIs Azure Classification Clustering Computer Science Seniorlevel',
#  'MachineLearningEngineer Agile APIs Architecture AWS Deep Learning DevOps Seniorlevel',
#  'DataEngineer Architecture AWS Azure Big Data Computer Science Data governance Seniorlevel',
#  'other Data visualization Data warehouse Data Warehousing Engineering ETL Oracle Seniorlevel',
#  'other Data management Engineering Industrial R R&D  Midlevel',
#  'other Banking Finance Genetics    Executivelevel',
#  'other APIs Architecture AWS BERT Classification Clustering Seniorlevel',
#  'DataScientist Architecture Big Data Data pipelines Economics Engineering Mathematics Seniorlevel',
#  'DataAnalyst Azure Consulting Data analysis DevOps Excel Finance Seniorlevel',
#  'other Airflow Architecture AWS Business Analytics CI/CD Databricks Seniorlevel',
#  'other Engineering Matlab PhD Python Research Robotics Unknown Experience Level',
#  'DataScientist CX Engineering Finance Machine Learning Mathematics Python Seniorlevel',
#  'other Agile Architecture AWS Big Data Business Intelligence CI/CD Seniorlevel',
#  'DataEngineer Athena Avro AWS Azure Big Data BigQuery Seniorlevel',
#  'SoftwareEngineer Architecture Engineering MS SQL OOP Python Research Seniorlevel',
#  'other Agile Architecture Business Intelligence Data analysis Data visualization Data Warehousing Seniorlevel',
#  'other BigQuery Business Intelligence Excel GCP JavaScript Power BI Unknown Experience Level',
#  'other Deep Learning Engineering Machine Learning Python Research  Seniorlevel',
#  'other Banking Computer Science Data Analytics Data management Security  Midlevel',
#  'other AI governance APIs Architecture Computer Science Consulting Data management Midlevel',
#  'DataScientist Causal inference Data Analytics Ecommerce Economics Engineering Machine Learning Executivelevel',
#  'DataEngineer Airflow Architecture BigQuery Finance FinTech GCP Midlevel',
#  'DataAnalyst Agile APIs Azure Databricks Data pipelines Engineering Unknown Experience Level',
#  'AIEngineer Computer Vision Consulting Data analysis Deep Learning Healthcare technology JavaScript Seniorlevel',
#  'DataEngineer Airflow Architecture Avro BigQuery Data quality Engineering Midlevel',
#  'other Agile Consulting Data management Data quality   Midlevel',
#  'DataAnalyst Agile Banking Data analysis Engineering ETL Finance Seniorlevel',
#  'DataAnalyst Business Intelligence Data visualization Economics Excel Finance KPIs Entrylevel',
#  'other Agile Airflow Banking Data pipelines Data quality Docker Seniorlevel',
#  'other Agile API Development APIs AWS Computer Science EC2 Midlevel',
#  'other APIs Computer Science Finance UX   Midlevel',
#  'other Agile Business Intelligence Computer Science Data governance Data management Data strategy Unknown Experience Level',
#  'DataEngineer Agile Azure Computer Science Databricks Data warehouse DevOps Unknown Experience Level',
#  'BIAnalyst Business Analytics Looker Python R SQL Tableau Seniorlevel',
#  'DataScientist A/B testing Biology Computer Science Data analysis EDA Engineering Seniorlevel',
#  'other Architecture Business Intelligence Data governance Finance Genetics Power BI Unknown Experience Level',
#  'DataEngineer Agile Architecture AWS Consulting EC2 Engineering Seniorlevel',
#  'DataEngineer Architecture AWS Big Data Business Intelligence Data pipelines Data quality Seniorlevel',
#  'DataScientist Airflow Banking Big Data Classification Clustering Consulting Midlevel',
#  'DataAnalyst A/B testing Airflow BigQuery Clustering Consulting Data Studio Seniorlevel',
#  'DataAnalyst Consulting Data analysis Security    Entrylevel',
#  'DataEngineer Airflow Architecture Athena AWS Computer Science DynamoDB Seniorlevel',
#  'other Computer Science Deep Learning Docker Engineering GCP GitLab Seniorlevel',
#  'DataAnalyst AWS Azure Computer Science Data analysis Data quality Data visualization Unknown Experience Level',
#  'DataEngineer Agile Airflow APIs Athena AWS Azure Unknown Experience Level',
#  'ResearchScientist Architecture Deep Learning Docker GCP GitLab Industrial Seniorlevel',
#  'other JavaScript Ruby Testing    Midlevel',
#  'other Business Analytics Data analysis Data quality Engineering Statistics  Seniorlevel',
#  'DataEngineer Architecture AWS Big Data Computer Science Data governance Data management Seniorlevel',
#  'other Agile Architecture Azure BERT Big Data Computer Science Seniorlevel',
#  'DataAnalyst CX Data quality Finance Spark   Entrylevel',
#  'other Agile Airflow Banking Data pipelines Data quality Docker Seniorlevel',
#  'DataAnalyst AWS Big Data Computer Science Data Analytics GCP Snowflake Seniorlevel',
#  'other CMake Computer Science Computer Vision Deep Learning Open Source PhD Seniorlevel',
#  'MachineLearningEngineer Industrial Machine Learning     Seniorlevel',
#  'ResearchScientist Computer Science Distributed Systems Engineering Golang Linear algebra Machine intelligence Entrylevel',
#  'other Caffe Computer Vision Deep Learning Engineering Linux Machine Learning Seniorlevel',
#  'other APIs Business Intelligence Computer Science Economics Excel Machine Learning Midlevel',
#  'DataEngineer Agile AWS Azure Cassandra Data management Engineering Seniorlevel',
#  'DataScientist Data analysis Engineering Git Linux Physics Python Entrylevel',
#  'other Machine Learning Python     Entrylevel',
#  'DataEngineer Architecture AWS Big Data Computer Science Data analysis Data governance Seniorlevel',
#  'other Agile Computer Science Data analysis Data management Data quality Economics Entrylevel',
#  'other AWS Computer Science DataOps Data visualization Excel GCP Unknown Experience Level',
#  'other Agile Big Data Computer Science Consulting Consulting firm Engineering Seniorlevel',
#  'other Architecture Engineering Mathematics OOP Testing VR Seniorlevel',
#  'DataEngineer Agile Azure Banking DevOps Engineering FinTech Entrylevel',
#  'other Agile Computer Science Data analysis Data management Data quality Economics Entrylevel',
#  'DataAnalyst APIs AWS ETL Jupyter Lambda Looker Entrylevel',
#  'other Engineering GitHub PhD Research Spark Testing Seniorlevel',
#  'DataEngineer Agile Architecture AWS Azure Big Data Cassandra Seniorlevel',
#  'DataAnalyst Data analysis Engineering Python R Research  Entrylevel',
#  'other Big Data Bitbucket CI/CD Data analysis Data governance DataOps Seniorlevel',
#  'DataAnalyst Airflow AWS Banking Data analysis Databricks FinTech Seniorlevel',
#  'Architect Agile APIs Architecture AWS Azure Computer Science Seniorlevel',
#  'Architect APIs Architecture JSON Model design Security SQL Seniorlevel',
#  'other Architecture Data management Excel Security   Seniorlevel',
#  'MachineLearningEngineer Computer Science Computer Vision Data pipelines Data quality Deep Learning Engineering Seniorlevel',
#  'SoftwareEngineer Agile Azure Data Analytics Databricks Excel Hadoop Seniorlevel',
#  'other Chatbots Computer Science Engineering Machine Learning Mathematics Statistics Seniorlevel',
#  'DataEngineer Airflow Big Data Consulting Consulting firm ELT Engineering Executivelevel',
#  'DataEngineer AWS Azure Computer Science Data governance Data management Data pipelines Midlevel',
#  'other Biology Drug discovery Engineering Genetics Healthcare technology PhD Seniorlevel',
#  'SoftwareEngineer APIs Architecture AWS Azure Computer Science CUDA Seniorlevel',
#  'DataScientist Economics Machine Learning Predictive modeling Python R SQL Seniorlevel',
#  'other Architecture Engineering Industrial Matlab Python R Seniorlevel',
#  'other Biology Data management Oracle Research Testing  Seniorlevel',
#  'DataAnalyst Economics Engineering FinTech Looker Mathematics Power BI Seniorlevel',
#  'DataScientist A/B testing Banking Data Mining Looker Python SQL Seniorlevel',
#  'SoftwareEngineer Agile Airflow APIs Architecture Athena AWS Seniorlevel',
#  'DataAnalyst Agile Azure Consulting Data analysis DevOps Excel Seniorlevel',
#  'DataEngineer AWS Banking ETL NLP Python SQL Entrylevel',
#  'other Engineering Power BI Security Testing   Midlevel',
#  'other API Development APIs Consulting Data analysis Data Analytics Data management Midlevel',
#  'other Banking Computer Science Consulting Finance FinTech Machine Learning Entrylevel',
#  'DataAnalyst A/B testing Data analysis Data management Data visualization Economics Excel Seniorlevel',
#  'other A/B testing Amplitude Big Data Business Intelligence Data visualization Data warehouse Entrylevel',
#  'other Computer Science Consulting Excel Machine Learning Research  Midlevel',
#  'DataScientist Biology Chemistry Classification Data analysis Data Mining Data visualization Unknown Experience Level',
#  'other Deep Learning Distributed Systems Hadoop Machine Learning ML models MXNet Seniorlevel',
#  'DataEngineer APIs Architecture AWS Azure Big Data CI/CD Seniorlevel',
#  'DataScientist Big Data Computer Science Hadoop Keras Machine Learning Mathematics Seniorlevel',
#  'MachineLearningEngineer Architecture ASR Bayesian ChatGPT Engineering GPT Seniorlevel',
#  'DataEngineer Agile Architecture AWS Azure Business Intelligence Data analysis Seniorlevel',
#  'DataScientist Computer Science Elasticsearch Engineering Machine Learning SQL Statistics Entrylevel',
#  'DataEngineer Airflow AWS Data pipelines ELT Engineering ETL Midlevel',
#  'other Ecommerce Engineering Linux Python Robotics Statistics Seniorlevel',
#  'other Ansible Athena AWS Elasticsearch Kafka Kinesis Seniorlevel',
#  'other Agile Architecture Big Data CI/CD Computer Science Computer Vision Seniorlevel',
#  'other Airflow APIs Architecture Data warehouse Data Warehousing Engineering Midlevel',
#  'DataEngineer Architecture AWS Azure CI/CD Computer Science Data analysis Seniorlevel',
#  'other Big Data Business Analytics Business Intelligence Computer Science Data Analytics Data pipelines Executivelevel',
#  'other Engineering Genetics Privacy Security Testing  Midlevel',
#  'MachineLearningEngineer Architecture Azure BigQuery Computer Science Distributed Systems Engineering Seniorlevel',
#  'DataAnalyst Computer Science Data analysis Data management Data visualization Data Warehousing ETL Midlevel',
#  'other Business Intelligence Data Analytics Power BI Python SAS SQL Entrylevel',
#  'other Engineering React TypeScript    Seniorlevel',
#  'other Airflow Architecture ASR AWS Classification Computer Science Seniorlevel',
#  'DataAnalyst Agile APIs Azure Databricks Data pipelines Engineering Midlevel',
#  'ResearchScientist Classification Computer Vision Deep Learning DICOM Machine Learning PhD Seniorlevel',
#  'other Architecture Engineering Industrial Matlab Python R Seniorlevel',
#  'DataScientist BigQuery Data pipelines Data visualization ELT Engineering ETL Unknown Experience Level',
#  'other Banking FinTech Machine Learning    Executivelevel',
#  'DataEngineer AWS Big Data Data Analytics Dataflow Elasticsearch Excel Seniorlevel',
#  'DataEngineer Agile Azure Computer Science Databricks Data warehouse ELT Seniorlevel',
#  'DataEngineer Agile Architecture Business Intelligence Computer Science Consulting Data analysis Seniorlevel',
#  'DataAnalyst Data Mining Data Studio Looker Power BI Statistics  Seniorlevel',
#  'other Computer Science Data Analytics Deep Learning Engineering Golang LangChain Seniorlevel',
#  'DataScientist Economics Engineering Mathematics Python R Research Seniorlevel',
#  'Architect Consulting Data analysis Data governance Security Statistics Unstructured data Seniorlevel',
#  'other Architecture AWS Databricks FinTech Kafka Machine Learning Midlevel',
#  'DataEngineer Architecture Business Intelligence Computer Science Data analysis Data Analytics Data Mining Seniorlevel',
#  'ResearchScientist AWS Azure Computer Vision Deep Learning DevOps Docker Seniorlevel',
#  'DataScientist Banking Blockchain Crypto Data analysis Data visualization Deep Learning Seniorlevel',
#  'DataAnalyst A/B testing Angular APIs Architecture Big Data BigQuery Seniorlevel',
#  'other Data Analytics Engineering Machine Learning Mathematics Physics  Entrylevel',
#  'Architect Agile Ansible AWS Big Data DevOps Docker Seniorlevel',
#  'other Architecture BigQuery Computer Science DataOps Data pipelines Data quality Seniorlevel',
#  'DataEngineer Agile APIs Architecture Data management Engineering Oracle Midlevel',
#  'DataAnalyst Business Intelligence KPIs Looker SQL   Executivelevel',
#  'DataAnalyst CX Data Analytics Ecommerce Engineering Excel KPIs Seniorlevel',
#  'MachineLearningEngineer Airflow AWS CX Databricks Engineering GitHub Seniorlevel',
#  'other APIs Data management Finance Git MySQL PHP Entrylevel',
#  'DataAnalyst BigQuery Data analysis Data Analytics Data strategy Data Studio Ecommerce Seniorlevel',
#  'other APIs Architecture Computer Science Engineering Finance JSON Midlevel',
#  'other Data management Data quality Data visualization Excel Python Security Unknown Experience Level',
#  'other Banking Engineering Mathematics Python R Robotics Seniorlevel',
#  'DataEngineer Agile Architecture AWS CI/CD Computer Science DevOps Seniorlevel',
#  'other AWS Business Intelligence Data analysis Data management Data quality Data Warehousing Seniorlevel',
#  'DataAnalyst Agile Banking Data analysis Engineering ETL Finance Seniorlevel',
#  'other A/B testing AWS Big Data Data Analytics Data visualization Economics Seniorlevel',
#  'other Airflow AWS Azure CI/CD Computer Science Dagster Midlevel',
#  'Architect Agile Architecture AWS Azure Business Intelligence Computer Science Midlevel',
#  'other Banking Blockchain Business Intelligence Computer Science Crypto Data Mining Seniorlevel',
#  'other Agile BigQuery Business Intelligence Data analysis ETL Looker Seniorlevel',
#  'other Data management Economics Finance Industrial Mathematics Power BI Unknown Experience Level',
#  'DevOpsEngineer Ansible AWS Azure CI/CD Computer Science DevOps Midlevel',
#  'other A/B testing Big Data Data Analytics Data warehouse Python R Entrylevel',
#  'DataAnalyst Airflow BigQuery Data Analytics Data visualization Engineering GCP Unknown Experience Level',
#  'DataAnalyst Agile Data analysis Data quality Data visualization Excel Privacy Seniorlevel',
#  'MachineLearningEngineer Airflow AWS Banking Blockchain Classification Computer Science Seniorlevel',
#  'other Engineering Machine Learning Robotics    Entrylevel',
#  'DataAnalyst Data quality Data visualization Python R SQL Statistics Seniorlevel',
#  'DataAnalyst Amplitude Python R SQL   Unknown Experience Level',
#  'DataAnalyst Consulting Data management Ecommerce GitHub SQL Tableau Entrylevel',
#  'other BigQuery CI/CD Data analysis Data pipelines Data quality Data warehouse Seniorlevel',
#  'DataAnalyst Industrial SQL     Entrylevel',
#  'DataEngineer Architecture ELT Engineering ETL Pipelines Redshift Seniorlevel',
#  'MachineLearningEngineer Azure Classification Ecommerce Engineering GCP Google Cloud Seniorlevel',
#  'DataEngineer Agile Architecture Computer Science Consulting CX Data warehouse Seniorlevel',
#  'DataEngineer Agile Airflow Architecture AWS Big Data Computer Science Seniorlevel',
#  'DataEngineer Architecture Azure Data analysis Databricks Data governance Data pipelines Midlevel',
#  'other Computer Science GPT GPT3 GPT4 HuggingFace LLMs Entrylevel',
#  'DataEngineer Airflow APIs Architecture Athena Azkaban Big Data Seniorlevel',
#  'other Power BI Tableau     Seniorlevel',
#  'SoftwareEngineer AWS DevOps Engineering GCP Git GitHub Midlevel',
#  'Architect Computer Science Computer Vision Deep Learning Engineering GitHub GPU Midlevel',
#  'DataEngineer Airflow Azure CI/CD Data governance DevOps Ecommerce Entrylevel',
#  'Architect Agile APIs Architecture Azure Big Data Business Intelligence Seniorlevel',
#  'DataAnalyst Data Analytics Power BI Tableau    Entrylevel',
#  'DataEngineer Airflow Architecture AWS Big Data Cassandra Data warehouse Midlevel',
#  'Architect Architecture AWS Big Data Data strategy Distributed Systems Engineering Seniorlevel',
#  'DataAnalyst Data management Mathematics SQL Statistics   Executivelevel',
#  'other Chemistry Computer Science Data analysis Deep Learning Engineering Machine Learning Seniorlevel',
#  'MachineLearningEngineer LLMs Machine Learning PhD Pipelines Research Testing Seniorlevel',
#  'other Agile Architecture Consulting CX Data Analytics Data strategy Midlevel',
#  'DataEngineer AI strategy Computer Science Data Analytics Deep Learning Engineering Machine Learning Seniorlevel',
#  'other Agile API Development APIs Architecture AWS Computer Science Midlevel',
#  'other Data quality Machine Learning Python SQL Tableau  Entrylevel',
#  'SoftwareEngineer Agile APIs Architecture Azure JavaScript Kubernetes Seniorlevel',
#  'SoftwareEngineer Architecture Data management Ruby    Seniorlevel',
#  'MachineLearningEngineer Banking Blockchain Computer Science Crypto Engineering Finance Seniorlevel',
#  'other Open Source Python Research    Entrylevel',
#  'DataEngineer Agile Airflow Athena AWS Big Data Computer Science Unknown Experience Level',
#  'other Computer Science Data management Data quality Engineering RDBMS  Midlevel',
#  'other APIs Architecture AWS CI/CD Databricks Docker Unknown Experience Level',
#  'DataScientist AWS Azure Computer Science Engineering Flink GCP Seniorlevel',
#  'other Agile APIs AWS Azure Computer Science Engineering Midlevel',
#  'SoftwareEngineer A/B testing Deep Learning Engineering Haystack Machine Learning ML models Seniorlevel',
#  'MachineLearningEngineer Architecture AWS Azure Big Data Computer Science Deep Learning Seniorlevel',
#  'other Computer Science Driver\x92s license Engineering Physics Python Robotics Seniorlevel',
#  'DataAnalyst Airflow Data quality GitHub Jira Privacy Python Seniorlevel',
#  'other Agile Airflow Architecture AWS Azure Cassandra Seniorlevel',
#  'other Agile Business Intelligence Computer Science Consulting CX Excel Seniorlevel',
#  'other APIs Finance FinTech    Seniorlevel',
#  'DataAnalyst Looker SQL     Seniorlevel',
#  'other Data visualization Excel Mathematics Power BI Research SQL Seniorlevel',
#  'other APIs Architecture Athena BigQuery Computer Science Data management Seniorlevel',
#  'other Data Analytics PhD Spark Testing   Midlevel',
#  'DataEngineer Airflow Architecture AWS Data management Data pipelines Docker Seniorlevel',
#  'DataScientist Architecture Bayesian BigQuery Business Intelligence Classification Clustering Seniorlevel',
#  'other Agile Azure Business Intelligence Data quality Data visualization Data warehouse Seniorlevel',
#  'other Angular APIs Azure Banking Finance Flask Entrylevel',
#  'DataScientist Big Data Computer Science Data analysis Genetics Machine Learning Mathematics Midlevel',
#  'DataAnalyst Agile Architecture AWS BigQuery Dataflow Data visualization Entrylevel',
#  'other AWS Data visualization Engineering ETL Qlik Redshift Seniorlevel',
#  'other APIs Data analysis Data Analytics Power BI Unstructured data  Entrylevel',
#  'DataAnalyst Ecommerce Python SQL    Seniorlevel',
#  'DataScientist APIs Blockchain Crypto Data analysis Data Analytics Engineering Midlevel',
#  'DataEngineer AWS Azure CX Data management Data Mining Data pipelines Seniorlevel',
#  'other Agile Business Intelligence Excel Finance Power BI Tableau Seniorlevel',
#  'other Business Intelligence Engineering Looker MongoDB Python R Seniorlevel',
#  'SoftwareEngineer Athena Avro AWS Big Data CI/CD Data Mining Unknown Experience Level',
#  'other Agile Business Intelligence Engineering Finance Kanban NLP Seniorlevel',
#  'SoftwareEngineer AWS DevOps Engineering GCP Git GitHub Midlevel',
#  'other Architecture Chatbots Deep Learning Engineering Excel JavaScript Seniorlevel',
#  'other Agile APIs Architecture Computer Science Data management Engineering Seniorlevel',
#  'DataScientist Big Data Business Intelligence Computer Science Excel Machine Learning Mathematics Unknown Experience Level',
#  'DataEngineer Agile Architecture AWS Azure Business Intelligence Data analysis Unknown Experience Level',
#  'SoftwareEngineer Agile APIs Architecture Azure JavaScript Kubernetes Seniorlevel',
#  'DataAnalyst Computer Science Economics Excel Finance Mathematics Power BI Midlevel',
#  'DataScientist AI strategy Computer Science Data analysis Data Analytics Deep Learning Engineering Seniorlevel',
#  'BIAnalyst Business Intelligence Data Analytics Data Mining Data Warehousing Engineering Excel Seniorlevel',
#  'MachineLearningEngineer Airflow Banking Computer Science Data analysis Data pipelines Deep Learning Seniorlevel',
#  'DevOpsEngineer Architecture AWS Azure CI/CD Data management DevOps Seniorlevel',
#  'other Big Data Business Intelligence Computer Science Consulting Data Mining Data warehouse Unknown Experience Level',
#  'other Architecture Data analysis Data visualization EDA Power BI SQL Entrylevel',
#  'DataEngineer Agile APIs AWS Azure Computer Science Data governance Midlevel',
#  'DataAnalyst Computer Science Data analysis Economics Excel Mathematics Python Midlevel',
#  'other Banking Business Analytics Classification Credit risk Data analysis Engineering Seniorlevel',
#  'MachineLearningEngineer Agile APIs AWS Computer Science Data governance Data pipelines Seniorlevel',
#  'other Architecture Business Intelligence Data analysis Data Analytics Data governance Data management Seniorlevel',
#  'other Autonomous Driving Computer Science Engineering GPU Machine Learning Mathematics Entrylevel',
#  'DataAnalyst Business Intelligence Computer Science Data analysis Data management Data quality Data visualization Seniorlevel',
#  'other Computer Science Data Analytics Engineering LLMs Machine Learning NLP Seniorlevel',
#  'other Airflow ELT ETL Parquet Pipelines Python Unknown Experience Level',
#  'other Agile Architecture Business Intelligence Data strategy Finance Jira Executivelevel',
#  'MachineLearningEngineer Computer Science Data analysis Engineering Keras Machine Learning ML models Seniorlevel',
#  'other Causal inference Computer Science Data analysis Data management Engineering Genetics Executivelevel',
#  'other Airflow APIs Architecture Avro Big Data BigQuery Seniorlevel',
#  'other Architecture Deep Learning Engineering Industrial OpenCV Python Seniorlevel',
#  'DataScientist Computer Science Consulting Data pipelines Economics Engineering Excel Seniorlevel',
#  'other APIs Azure Business Intelligence Data analysis Data Analytics Databricks Unknown Experience Level',
#  'DataEngineer Agile Airflow Big Data Business Intelligence Computer Science Data Analytics Midlevel',
#  'other AWS CI/CD Deep Learning DevOps Docker EC2 Midlevel',
#  'DataEngineer Agile APIs Architecture Banking Big Data CI/CD Seniorlevel',
#  'DataAnalyst Agile Scrum Tableau    Midlevel',
#  'other Distributed Systems Industrial JavaScript Python Robotics  Entrylevel',
#  'Architect Architecture Azure Big Data Computer Science Data governance Data strategy Seniorlevel',
#  'SoftwareEngineer Agile Angular APIs Architecture AWS Azure Entrylevel',
#  'DataEngineer Agile APIs Architecture Azure DevOps ELT Midlevel',
#  'DataEngineer Agile APIs Azure CI/CD Computer Science Data pipelines Seniorlevel',
#  'other Architecture Big Data Computer Science Data analysis Deep Learning Engineering Entrylevel',
#  'DataAnalyst Business Intelligence Excel Power BI SQL   Entrylevel',
#  'SoftwareEngineer Big Data Engineering Finance SQL STEM  Midlevel',
#  'other AWS Big Data Business Intelligence Data analysis Data Analytics Data pipelines Entrylevel',
#  'DataScientist Architecture AWS Azure Computer Science Data Mining Engineering Midlevel',
#  'DataAnalyst Blockchain Crypto Data analysis Engineering Finance Mathematics Entrylevel',
#  'other Architecture AWS Azure Big Data Cassandra Consulting Seniorlevel',
#  'MachineLearningEngineer Architecture Computer Science Deep Learning Engineering Machine Learning ML models Unknown Experience Level',
#  'other Data quality Machine Learning MLOps Model training Security Statistics Seniorlevel',
#  'DataEngineer Amplitude Angular Engineering JavaScript React Statistics Midlevel',
#  'DataEngineer Agile Architecture AWS BigQuery Dataflow Data visualization Entrylevel',
#  'DataEngineer AWS Banking ETL NLP Python SQL Midlevel',
#  'DataEngineer Azure Banking Data analysis Databricks Data Mining Engineering Midlevel',
#  'DataScientist Agile AWS Machine Learning Mathematics ML models Plotly Seniorlevel',
#  'DataScientist A/B testing Computer Science Databricks Engineering Genetics Machine Learning Seniorlevel',
#  'other Agile Architecture AWS Azure Computer Science Consulting Seniorlevel',
#  'other Big Data Business Intelligence Computer Science D3 Git JavaScript Midlevel',
#  'DataScientist Agile AWS Big Data Computer Science Computer Vision Data analysis Seniorlevel',
#  'other Architecture Engineering Mathematics OOP VR  Seniorlevel',
#  'DataAnalyst Athena AWS Big Data Business Intelligence Data analysis Data Analytics Entrylevel',
#  'other Autonomous Driving Big Data Circuit Design Computer Science Deep Learning EMNLP Entrylevel',
#  'DataScientist AWS Azure Big Data Computer Science Data analysis Data Mining Midlevel',
#  'other Architecture Big Data Computer Science Data analysis Deep Learning Engineering Entrylevel',
#  'other Data Analytics Data management Engineering Excel Industrial Statistics Seniorlevel',
#  'DataScientist Big Data Economics Finance Machine Learning Mathematics ML infrastructure Unknown Experience Level',
#  'DataScientist Causal inference Data governance Ecommerce Engineering Python R Seniorlevel',
# ...
#  'Architect Consulting Engineering Mathematics    Executivelevel',
#  'other APIs Architecture JSON Model design Security SQL Seniorlevel',
#  'Architect Architecture Classification Data analysis Data Analytics Python Teaching Entrylevel',
#  'other Architecture Big Data Computer Science Databricks Deep Learning Engineering Seniorlevel',
#  'other Data Analytics Excel Security    Seniorlevel',
#  'DataScientist Agile Airflow Architecture Avro BigQuery Blockchain Unknown Experience Level',
#  'DataAnalyst Airflow Data quality Excel Machine Learning ML models Pandas Seniorlevel',
#  'DataAnalyst Banking Computer Science Consulting Data analysis Data visualization Ecommerce Midlevel',
#  'DataEngineer Big Data Computer Science Data Analytics Databricks Economics Finance Seniorlevel',
#  'other Airflow AWS Big Data Computer Science Data analysis Databricks Seniorlevel',
#  'DataAnalyst Agile AWS Azure Business Intelligence Consulting DevOps Unknown Experience Level',
#  'other A/B testing Banking Business Intelligence Computer Science Consulting Data analysis Midlevel',
#  'other Architecture BigQuery Dataflow Data strategy Engineering ETL Executivelevel',
#  'other Airflow APIs Architecture AWS BigQuery CI/CD Seniorlevel',
#  'DataAnalyst Agile AI governance Architecture Big Data Deep Learning Engineering Seniorlevel',
#  'DataAnalyst Agile Scrum Tableau    Midlevel',
#  'other Data Analytics Data visualization Excel Finance PhD Power BI Unknown Experience Level',
#  'DataAnalyst Architecture Machine Learning Python PyTorch R R&D Entrylevel',
#  'MachineLearningEngineer Business Intelligence Data visualization Econometrics Genetics Research Statistics Seniorlevel',
#  'DataAnalyst Agile Architecture Bayesian Computer Science Computer Vision Deep Learning Midlevel',
#  'other Computer Science Data Warehousing Elasticsearch Engineering JavaScript NoSQL Unknown Experience Level',
#  'other Computer Vision Deep Learning Distributed Systems Engineering Hadoop Machine Learning Seniorlevel',
#  'DataScientist Data Analytics Dataflow Data governance Data management Data quality Ecommerce Executivelevel',
#  'other Azure CI/CD Classification Clustering Data Analytics Data strategy Unknown Experience Level',
#  'other ETL Oracle PostgreSQL SQL XML XSD Seniorlevel',
#  'DataEngineer Azure DevOps Industrial Pipelines Power BI SQL Seniorlevel',
#  'other Airflow AWS CI/CD Computer Vision Databricks Data governance Seniorlevel',
#  'other APIs Architecture CX Engineering Kubernetes Machine Learning Seniorlevel',
#  'DataEngineer Computer Science Data governance Power BI Research   Seniorlevel',
#  'other Architecture Computer Science SQL Testing   Midlevel',
#  'other Big Data Classification Engineering Machine Learning ML models Research Executivelevel',
#  'DataAnalyst Blockchain Crypto Engineering FinTech Machine Learning Privacy Seniorlevel',
#  'DataAnalyst Data Studio Data warehouse Data Warehousing Engineering ETL Looker Midlevel',
#  'other A/B testing Banking Business Intelligence Computer Science Consulting Data analysis Seniorlevel',
#  'DataScientist Data Analytics DevOps Engineering Genetics Security Statistics Executivelevel',
#  'MachineLearningEngineer Bayesian Big Data BigQuery Causal inference Computer Science Data analysis Unknown Experience Level',
#  'DataAnalyst BigQuery Bigtable Computer Science Dataflow Data pipelines Engineering Entrylevel',
#  'other Computer Science Data analysis Data quality Data visualization ELT Engineering Seniorlevel',
#  'other APIs BigQuery CI/CD Data Analytics Data pipelines Data quality Entrylevel',
#  'ResearchScientist AWS Business Intelligence Data Mining Data visualization Data warehouse DynamoDB Seniorlevel',
#  'other Data visualization Deep Learning Machine Learning Mathematics Python R Seniorlevel',
#  'other Architecture AWS Azure Data Analytics Machine Learning PhD Seniorlevel',
#  'SoftwareEngineer Engineering Matlab PhD Physics Python R Midlevel',
#  'DataEngineer AGI APIs Architecture Azure ChatGPT DALLE Seniorlevel',
#  'other Airflow AWS BigQuery Business Intelligence Databricks Data pipelines Seniorlevel',
#  'other Data management Excel GCP Statistics   Unknown Experience Level',
#  'other Architecture Computer Vision Deep Learning Genetics Machine Learning Model inference Seniorlevel',
#  'Architect Agile Data Analytics Data management Engineering JSON Python Entrylevel',
#  'other Architecture Big Data Consulting Databricks Data Warehousing Engineering Seniorlevel',
#  'DataScientist Agile Amplitude Blockchain Computer Science Crypto Data analysis Seniorlevel',
#  'MachineLearningEngineer A/B testing Agile CI/CD Computer Science Data visualization Docker Seniorlevel',
#  'other Architecture AWS Banking Big Data Blockchain Computer Science Seniorlevel',
#  'DataAnalyst Business Intelligence Data analysis Data Analytics Data Mining Data visualization Economics Seniorlevel',
#  'DataAnalyst Agile Banking Data management Data Studio Excel FinTech Entrylevel',
#  'other Agile APIs Business Analytics Business Intelligence Computer Science Data governance Seniorlevel',
#  'other Computer Vision GloVe     Unknown Experience Level',
#  'other Computer Vision Deep Learning Docker Git Linux Machine Learning Entrylevel',
#  'other Computer Vision Deep Learning Engineering Machine Learning Matlab Python Seniorlevel',
#  'other Consulting Economics Machine Learning Privacy Research  Seniorlevel',
#  'DataScientist Business Intelligence CX Data quality Data visualization Ecommerce Engineering Seniorlevel',
#  'other Causal inference Data Analytics Ecommerce Economics Engineering Machine Learning Seniorlevel',
#  'DataEngineer Agile AWS Azure Data analysis Data Analytics Data Studio Seniorlevel',
#  'other Architecture AWS Azure Consulting Consulting firm Data pipelines Midlevel',
#  'DataScientist Architecture Engineering Jira Mathematics OOP Research Executivelevel',
#  'DataEngineer Big Data Computer Science Data analysis Data Analytics Engineering Linux Unknown Experience Level',
#  'DataScientist Agile Airflow APIs Azure Big Data Business Intelligence Seniorlevel',
#  'DataAnalyst Credit risk Data analysis Data Analytics Data Mining Econometrics Engineering Seniorlevel',
#  'other Agile Business Intelligence Scrum Spark   Seniorlevel',
#  'DataEngineer Blockchain Crypto Data analysis Data management Finance Research Seniorlevel',
#  'other Airflow Angular APIs Architecture AWS Azure Seniorlevel',
#  'SoftwareEngineer Deep Learning FinTech Machine Learning Python PyTorch R Entrylevel',
#  'DataScientist Agile APIs AWS Engineering ETL KPIs Seniorlevel',
#  'DataEngineer CX Data analysis Engineering Excel Finance GitHub Seniorlevel',
#  'DataEngineer Airflow Distributed Systems Elasticsearch Flink Golang Kafka Seniorlevel',
#  'DataAnalyst Computer Science Data management Data Mining Data pipelines Data quality Engineering Midlevel',
#  'MachineLearningEngineer A/B testing Amplitude Data Studio Data visualization Finance Looker Seniorlevel',
#  'DataEngineer Amplitude BigQuery Data visualization Docker FinTech Kubernetes Seniorlevel',
#  'Architect Airflow AWS Data governance Data quality Engineering ETL Seniorlevel',
#  'other Architecture Computer Science Consulting Data Analytics Data management Data visualization Midlevel',
#  'DataAnalyst CX Engineering Machine Learning ML models   Executivelevel',
#  'DataEngineer Computer Science Data Analytics Data Mining Economics Excel Mathematics Midlevel',
#  'MachineLearningEngineer Agile Airflow Big Data Data pipelines Data warehouse Elasticsearch Entrylevel',
#  'other Computer Science Deep Learning Engineering Genetics Machine Learning NLP Seniorlevel',
#  'DataAnalyst Agile APIs AWS Azure Consulting Databricks Seniorlevel',
#  'DataEngineer Airflow Big Data Classification Clustering Data analysis Databricks Seniorlevel',
#  'other Azure BigQuery Bigtable Computer Science Databricks Data pipelines Midlevel',
#  'other Ansible Architecture Big Data BigQuery GCP Genetics Seniorlevel',
#  'other Architecture Azure CX Data pipelines Data visualization Engineering Seniorlevel',
#  'AIEngineer APIs Autonomous Driving Big Data Circuit Design Computer Science Deep Learning Entrylevel',
#  'DataEngineer Computer Science Deep Learning Engineering Linux Machine Learning Mathematics Midlevel',
#  'other APIs Data Analytics Engineering MongoDB Node.js Python Midlevel',
#  'DataEngineer Engineering Machine Learning Research    Seniorlevel',
#  'AIEngineer Airflow Architecture Azure Big Data CI/CD Computer Science Seniorlevel',
#  'ResearchScientist Computer Science Machine Learning Python Research   Midlevel',
#  'other AWS Chemistry Computer Science Engineering ICLR ICML Seniorlevel',
#  'other Architecture Blockchain Business Intelligence Computer Science Engineering Looker Seniorlevel',
#  'other Business Intelligence Computer Science Data analysis Data Analytics Data Mining Privacy Seniorlevel',
#  'other Computer Science Data Mining Data quality Engineering Machine Learning Mathematics Unknown Experience Level',
#  'DataEngineer Azure Business Intelligence Data warehouse Engineering ETL Informatica Entrylevel',
#  'DataScientist Airflow Architecture Computer Science Data governance Data management DataOps Seniorlevel',
#  'DataEngineer Agile AWS Excel Machine Learning NumPy Pandas Entrylevel',
#  'DataEngineer Agile Airflow Architecture Azure Big Data Business Intelligence Seniorlevel',
#  'DataAnalyst Airflow APIs AWS Data Analytics DataOps DevOps Entrylevel',
#  'other Data Studio Ecommerce Excel GCP Hadoop Power BI Seniorlevel',
#  'other Agile Computer Science Data analysis Data Analytics Economics Engineering Entrylevel',
#  'other Data governance DataOps Engineering KPIs PhD Research Unknown Experience Level',
#  'other Architecture AWS Computer Science CX Data Analytics Data Mining Executivelevel',
#  'DataScientist AWS Azure Credit risk Data analysis Data Analytics Data Mining Entrylevel',
#  'MachineLearningEngineer Agile Big Data Computer Science Economics Engineering Genetics Executivelevel',
#  'MachineLearningEngineer Docker Engineering Kubernetes Machine Learning MLOps Python Seniorlevel',
#  'DataEngineer AWS Computer Science Computer Vision Deep Learning Docker Engineering Seniorlevel',
#  'other APIs Architecture AWS Big Data CI/CD Data analysis Seniorlevel',
#  'other Airflow Banking BigQuery Blockchain Crypto Engineering Seniorlevel',
#  'Architect AWS Bayesian Biology Computer Science EC2 ECS Seniorlevel',
#  'ResearchScientist APIs Architecture Big Data Business Intelligence Computer Science Data Analytics Seniorlevel',
#  'other AWS Biology Chemistry Computer Science Computer Vision Deep Learning Midlevel',
#  'DataAnalyst Data analysis Data management DataOps Jira Linux Python Executivelevel',
#  'DataEngineer Data Analytics ELT Looker OKR Python R Seniorlevel',
#  'other Agile Architecture Big Data Computer Science Engineering Testing Seniorlevel',
#  'DevOpsEngineer Computer Science Data Analytics Data pipelines Data quality Engineering Pipelines Seniorlevel',
#  'DataAnalyst Agile Azure Big Data Computer Science Consulting DevOps Seniorlevel',
#  'other AWS Azure Big Data Computer Science Consulting Data analysis Midlevel',
#  'DataScientist Architecture AWS Azure Cluster analysis Computer Science Consulting Seniorlevel',
#  'MachineLearningEngineer A/B testing AWS Deep Learning GitHub Lambda Machine Learning Unknown Experience Level',
#  'other APIs Causal inference Deep Learning Engineering LLMs Machine Learning Seniorlevel',
#  'Architect Computer Science Deep Learning Engineering Machine Learning PhD Pipelines Seniorlevel',
#  'other Agile Architecture AWS Azure Cluster analysis Computer Science Seniorlevel',
#  'other Data quality SLAM     Entrylevel',
#  'other Banking Blockchain Credit risk Crypto Data analysis Data pipelines Seniorlevel',
#  'DataAnalyst Bitbucket ELT ETL Git Jira Python Entrylevel',
#  'DataScientist Computer Science Consulting Databricks Economics Engineering Excel Seniorlevel',
#  'other Business Intelligence Causal inference Economics Finance Mathematics Privacy Seniorlevel',
#  'other Business Intelligence Consulting Excel Genetics Power BI Robotics Midlevel',
#  'DataAnalyst Business Intelligence Excel Genetics    Entrylevel',
#  'other Agile Data Analytics Research    Midlevel',
#  'DataScientist Business Intelligence Consulting Engineering Excel Finance Research Entrylevel',
#  'DataScientist Computer Science Data analysis Economics Machine Learning Mathematics NLP Seniorlevel',
#  'other Banking Blockchain Engineering ETL Matplotlib NumPy Unknown Experience Level',
#  'other Consulting Data Analytics     Entrylevel',
#  'other Data Mining Engineering Linux Machine Learning PhD Python Seniorlevel',
#  'SoftwareEngineer Big Data Business Analytics Computer Science Data Analytics Distributed Systems Economics Executivelevel',
#  'other Architecture Cybernetics DataRobot Drones Lidar Linux Seniorlevel',
#  'other Economics Engineering Machine Learning ML models Privacy Research Seniorlevel',
#  'other AWS Big Data FinTech Hadoop Machine Learning Pipelines Entrylevel',
#  'other Data analysis Genetics Market research Research SQL Statistics Seniorlevel',
#  'other Big Data Bitbucket CI/CD Data analysis Data governance DataOps Seniorlevel',
#  'other Airflow Architecture Avro AWS Big Data Business Intelligence Seniorlevel',
#  'DataEngineer Data Analytics Industrial     Seniorlevel',
#  'DataEngineer Agile API Development APIs Architecture Azure Big Data Seniorlevel',
#  'Architect Agile Architecture Big Data Clustering Computer Science Data governance Seniorlevel',
#  'other Architecture Classification Data governance Data quality ELT ETL Midlevel',
#  'DataScientist Engineering FinTech LLMs NLP   Entrylevel',
#  'other Airflow APIs Architecture Business Analytics Computer Science Data analysis Seniorlevel',
#  'DataAnalyst Agile Banking Data Warehousing ETL Finance Jira Seniorlevel',
#  'DataAnalyst Big Data Data Analytics Data governance Excel Python SQL Entrylevel',
#  'DataScientist Amplitude Data analysis Data visualization KPIs Python R Unknown Experience Level',
#  'other Economics Engineering Mathematics Python R Research Seniorlevel',
#  'DataEngineer Computer Science HuggingFace LLMs Machine Learning ML models MLOps Seniorlevel',
#  'other Data Warehousing ETL GitLab Python SQL  Entrylevel',
#  'DataEngineer Airflow Architecture ASR AWS Classification Computer Science Seniorlevel',
#  'other Ansible API Development APIs Architecture AWS CI/CD Midlevel',
#  'DataEngineer Business Intelligence Computer Science Data analysis Data governance Data visualization Data warehouse Seniorlevel',
#  'DataEngineer Agile APIs Azure Databricks Data governance Machine Learning Seniorlevel',
#  'other Architecture Big Data Computer Science Engineering Hadoop Kafka Executivelevel',
#  'DataEngineer Architecture Business Intelligence Data management Data quality Data warehouse Engineering Unknown Experience Level',
#  'DataAnalyst Agile Big Data Consulting Consulting firm Databricks Data pipelines Unknown Experience Level',
#  'DataAnalyst Data Analytics Excel KPIs Periscope Power BI Tableau Seniorlevel',
#  'DataAnalyst Big Data Computer Science Consulting CX Data Mining Ecommerce Seniorlevel',
#  'DataScientist A/B testing Angular APIs Architecture Big Data BigQuery Seniorlevel',
#  'other A/B testing Architecture Computer Science Data Analytics Data Mining Data strategy Seniorlevel',
#  'other CMake Computer Science Computer Vision Deep Learning Machine Learning Open Source Seniorlevel',
#  'DataScientist Computer Science Engineering GitHub Industrial Machine Learning Physics Entrylevel',
#  'other Engineering Perl Python SQL   Seniorlevel',
#  'other Agile APIs Elasticsearch Engineering Linux LLMs Entrylevel',
#  'MachineLearningEngineer Agile AWS Azure Big Data CI/CD Data visualization Seniorlevel',
#  'other BigQuery Bigtable Computer Science Computer Vision Dataflow Data pipelines Seniorlevel',
#  'other Big Data Data Analytics Data visualization Engineering Excel Looker Seniorlevel',
#  'other Business Intelligence CX Data analysis Genetics   Entrylevel',
#  'DataScientist Big Data Engineering Machine Learning OKR Testing  Seniorlevel',
#  ...]

# %%
# BERTopic model
ctfidf_model = ClassTfidfTransformer()
load_model_time = time.time()
topic_model = BERTopic(embedding_model = embedding_model,
                       calculate_probabilities=True,
                       hdbscan_model = cluster_model,
                       nr_topics = 10,
                       ctfidf_model = ctfidf_model  # extract topic words wihto TF-IDF, but instead of term-doc calculate as term-topic)
                      )
end_load_model = time.time()
print("Total time to load model: ", end_load_model - load_model_time)
# Out:
# Total time to load model:  0.0

# %%
# Fit the model on a corpus
load_model_time = time.time()
topics, probs = topic_model.fit_transform(docs)
end_load_model = time.time()
print("Total time to load model: ", end_load_model - load_model_time)
# Out:
# Total time to load model:  20.830671072006226

# %%
# Visualization examples: See [3] for more details
load_model_time = time.time()
# Save intertopic distance map as HTML file
# topic_model.visualize_topics().write_html(folder_path +"intertopic_dist_map.html")
topic_model.visualize_topics().write_html("intertopic_dist_map.html")
print("Total time to load model: ", end_load_model - load_model_time)
# Out:
# Total time to load model:  -182.11826848983765

# %%
load_model_time = time.time()
# Save topic-terms barcharts as HTML file
topic_model.visualize_barchart(top_n_topics = 25).write_html("barchart.html")
end_load_model = time.time()
print("Total time to load model: ", end_load_model - load_model_time)
# Out:
# Total time to load model:  0.0658717155456543

# %%
load_model_time = time.time()
# Save documents projection as HTML file
topic_model.visualize_documents(docs).write_html("projections.html")

# Save topics dendrogram as HTML file
topic_model.visualize_hierarchy().write_html("hieararchy.html")
end_load_model = time.time()
print("Total time to load model: ", end_load_model - load_model_time)
# Out:
# Total time to load model:  13.11623740196228

# %%
# Evaluate model 
# Reference: https://github.com/MaartenGr/BERTopic/issues/90
documents = pd.DataFrame({"Document": docs,
                          "ID": range(len(docs)),
                          "Topic": topics})
documents_per_topic = documents.groupby(['Topic'], as_index=False).agg({'Document': ' '.join})
cleaned_docs = topic_model._preprocess_text(documents_per_topic.Document.values)

# Extract vectorizer and analyzer from BERTopic
vectorizer = topic_model.vectorizer_model
analyzer = vectorizer.build_analyzer()

# Extract features for Topic Coherence evaluation
words = vectorizer.get_feature_names_out() # earlier version of this function is get_feature_names()
tokens = [analyzer(doc) for doc in cleaned_docs]
dictionary = corpora.Dictionary(tokens)
corpus = [dictionary.doc2bow(token) for token in tokens]
topic_words = [[words for words, _ in topic_model.get_topic(topic)] 
               for topic in range(len(set(topics))-1)]

# Evaluate
coherence_model_bertopic = CoherenceModel(topics=topic_words, 
                                 texts=tokens, 
                                 corpus=corpus,
                                 dictionary=dictionary, 
                                 coherence='c_v')
coherence_bertopic = coherence_model_bertopic.get_coherence()
print("Bertopic Coherence C_V is: {0}".format(coherence_bertopic))
# Out:
# Bertopic Coherence C_V is: 0.4306240670898964

# %%
df = topic_model.get_topic_info()
df.to_csv('output.csv')
df
# Out:
#    Topic  Count                                         Name  \
# 0     -1    955        -1_data_other_engineering_seniorlevel
# 1      0   1301                 0_data_aws_seniorlevel_azure
# 2      1    375             1_learning_machine_deep_computer
# 3      2    241     2_entrylevel_business_intelligence_excel
# 4      3     95                      3_docker_ansible_aws_ci
# 5      4     79      4_blockchain_crypto_banking_seniorlevel
# 6      5     58  5_chatbots_robotics_seniorlevel_engineering
# 7      6     41          6_privacy_machine_research_learning
# 8      7     36         7_causal_inference_economics_machine
# 9      8     16            8_angular_testing_javascript_apis
#
#                                       Representation  \
# 0  [data, other, engineering, seniorlevel, learni...
# 1  [data, aws, seniorlevel, azure, architecture, ...
# 2  [learning, machine, deep, computer, science, e...
# 3  [entrylevel, business, intelligence, excel, py...
# 4  [docker, ansible, aws, ci, cd, azure, computer...
# 5  [blockchain, crypto, banking, seniorlevel, sci...
# 6  [chatbots, robotics, seniorlevel, engineering,...
# 7  [privacy, machine, research, learning, enginee...
# 8  [causal, inference, economics, machine, engine...
# 9  [angular, testing, javascript, apis, react, bi...
#
#                                  Representative_Docs
# 0  [other AWS Computer Science Data Mining Excel ...
# 1  [DataEngineer Agile AWS Big Data Computer Scie...
# 2  [DataAnalyst Computer Science Computer Vision ...
# 3  [DataEngineer Business Intelligence Data analy...
# 4  [DataScientist AWS Azure CI/CD Computer Scienc...
# 5  [other Banking Blockchain Computer Science Cry...
# 6  [DataAnalyst Agile APIs Architecture Chatbots ...
# 7  [other Big Data Engineering Genetics Machine L...
# 8  [DataScientist Causal inference Computer Scien...
# 9  [DataAnalyst A/B testing Angular APIs Computer...

# %%
end_time = time.time()
print("Total script time: ",  end_time-script_start_time )
# Out:
# Total script time:  338.68249773979187
